# %%
# Dependencies
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import os
import cv2

# %%
 # Keras
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
# Out:
# C:\Users\Rudy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Rudy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Rudy\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
def process(DATADIR):
    images = []
    labels = []
    label = 0
    
    for labels in os.listdir(DATADIR):
        if labels == 'cardboard':
            label = 1
        elif labels == 'glass':
            label = 2
        elif labels == 'metal':
            label = 3 
        elif labels == ' paper':
            label = 4
        elif labels == 'plastic':
            label = 5
        elif labels == 'potholes':
            label = 6 
        elif labels == 'road_cracks':
            label = 7
        elif labels == 'trash':
            label = 8
        
        for images in os.listdir(DATADIR + labels):
            image = cv2.imread(DATADIR + r'/' + labels + r'/' + images)
            image = cv2.resize(image, (224, 224))
            images.append(image)
            labels.append(label)
    return shuffle(images, labels, random_state=42)

# %%
DATADIR = "c:/Users/Rudy/Desktop/DataViz/RoadHazardImageClassification/data"
os.listdir(DATADIR)
images, labels = process(DATADIR)
print(len(images), len(labels))

images = np.array(images) # converts list of images to numpy array
labels = np.array(labels)
print('Shape of Images:', images.shape)
print('Shape of Labels:', labels.shape)

# %%
DATADIR = "c:/Users/Rudy/Desktop/DataViz/RoadHazardImageClassification/data"
CATEGORIES = ['cardboard', 'glass', 'metal',
              'paper', 'plastic','potholes', 
              'road_cracks', 'trash']

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap='gray')
        plt.show()
        break
    break

# %%
# Print pixel data
print(img_array.shape)
print(img_array)
# Out:
# (384, 512)
# [[208 208 209 ... 180 182 183]
#  [209 210 211 ... 181 182 182]
#  [211 212 212 ... 182 181 181]
#  ...
#  [155 156 158 ...  95  95  95]
#  [155 155 155 ...  94  95  95]
#  [157 155 153 ...  94  95  95]]

# %%
img_size = 75 # increase based on size of desired item in image

new_array = cv2.resize(img_array, (img_size, img_size))
plt.imshow(new_array, cmap='inferno')
plt.show()
